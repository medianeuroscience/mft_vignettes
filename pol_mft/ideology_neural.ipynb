# %% [markdown]
# # Political ideology modulates neural responses to moral foundation vignettes

# %% [markdown]
# This notebook documents the analyses linking political orientation to the neural processing of the MFV.

# %% [markdown]
# ## Group-Level Repeated-Measures ANOVA

# %% [markdown]
# Because the second-level maps were created in the SPM GUI, we only report the results of the contrasts here. For model design and setup, we refer the reader to the SPM.mat file.

# %%
from atlasreader import create_output
# Out:
# The Python package you are importing, AtlasReader, is licensed under the
# BSD-3 license; however, the atlases it uses are separately licensed under more
# restrictive frameworks.
# By using AtlasReader, you agree to abide by the license terms of the
# individual atlases. Information on these terms can be found online at:
# https://github.com/miykael/atlasreader/tree/master/atlasreader/data
# /usr/local/miniconda3/envs/naturalistic/lib/python3.7/site-packages/nilearn/datasets/__init__.py:90: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %%
stat_img = 'ind_bind.nii'
create_output(stat_img, outdir='ind>bind', cluster_extent=0, voxel_thresh=4.06, direction='pos')
# Out:
# /usr/local/miniconda3/envs/naturalistic/lib/python3.7/site-packages/nilearn/_utils/niimg.py:62: UserWarning: Non-finite values detected. These values will be replaced with zeros.
#   "Non-finite values detected. "
# /usr/local/miniconda3/envs/naturalistic/lib/python3.7/site-packages/nilearn/_utils/niimg.py:62: UserWarning: Non-finite values detected. These values will be replaced with zeros.
#   "Non-finite values detected. "

# %%
from nilearn.plotting import plot_glass_brain
from nltools import Brain_Data

# %%
plot_glass_brain(Brain_Data('ind_bind.nii').to_nifti(), colorbar=True)
# Out:
# /usr/local/miniconda3/envs/naturalistic/lib/python3.7/site-packages/nilearn/image/resampling.py:598: RuntimeWarning: NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.
#   fill_value=fill_value)

# %%
plot_glass_brain(Brain_Data('bind_ind.nii').to_nifti(), colorbar=True)
# Out:
# /usr/local/miniconda3/envs/naturalistic/lib/python3.7/site-packages/nilearn/image/resampling.py:598: RuntimeWarning: NaNs or infinite values are present in the data passed to resample. This is a bad thing as they make resampling ill-defined and much slower.
#   fill_value=fill_value)

# %% [markdown]
# ***
